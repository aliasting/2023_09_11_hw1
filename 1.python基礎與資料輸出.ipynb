# %%
#純值運算
#python 純值
'Hello! Python!'
30
30.0
True
# Out:
# True

# %%
print('Hello! Python!')
# Out:
# Hello! Python!

# %%
#print()
print('Hello! Python!')
print(30)
print(30.0)
print(True)
# Out:
# Hello! Python!
# 30
# 30.0
# True

# %%
#整數運算
print(5 + 8)
print(90 - 10)
print(4 * 7)
print(6 / 2)
print(7 // 2)
print(7 % 3)
print(999 ** 20)
# Out:
# 13
# 80
# 28
# 3.0
# 3
# 1
# 980188864829534682605802224588165892518744500843860189980001

# %%
#浮點數和整數運算
print(5.0 + 8)
print(5.0 + 8 + 10)
print(5.0 + 8 * 2)
print(2 * (1 + 2) ** 2 - 2 ** 2 * 2)
# Out:
# 13.0
# 23.0
# 21.0
# 10

# %%
#字串的加法運算
"abc" + "efg"
# Out:
# 'abcefg'

# %%
#字串+數值 -> 出錯
#"abc" + 13

# %%
#str() -> 轉為字串
"abc" + str(13)
# Out:
# 'abc13'

# %%
#int() -> 轉為整數
int("13") + int("25")
# Out:
# 38

# %%
#float() -> 轉為浮點數
float("13.5") + float("21.7")
# Out:
# 35.2

# %%
openedx =100
openedx
# Out:
# 100

# %%
#taiwan, years = '台灣', 2018
#del years
taiwan ='台灣'
years = 2018
taiwan  
years
del years

# %%
#變數命名的規則
#開頭第一個字不能是數字。
#可使用大小寫字母或「_」。
#不可與內建保留字 (右邊表格所列) 同名。
#Python 3 可以使用中文名稱。
#大小寫視為不同的變數。
#不可以出現特殊字元或空白。
#合法命名
#• a  
#• a1  
#• a_b_c___95  
#• _abc  
#• _1a  
#不合法命名
#• 1 
#• 1a  
#• 1_

# %%
#question: 請問以下哪一個變數命名是錯的?(選擇題)
#(1) 5well.
#(2) pcschool
#(3) 巨匠
答:有下定義就都可以

# %%
5well
# Out:
#   Cell In[16], line 1
#     5well
#     ^
# SyntaxError: invalid decimal literal

# %%
name = '5well'

# %%
pcschool
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\職訓\第二周\第二周\0911\徐國堂0911\GitHub\2023_09_11_hw1\1.python基礎與資料輸出.ipynb 儲存格 16 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> pcschool
#
# NameError: name 'pcschool' is not defined

# %%
name = 'pcschool'

# %%
巨匠
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\職訓\第二周\第二周\0911\徐國堂0911\GitHub\2023_09_11_hw1\1.python基礎與資料輸出.ipynb 儲存格 17 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> 巨匠
#
# NameError: name '巨匠' is not defined

# %%
name = "巨匠"

# %%
#question: 請問以下哪一個變數命名是錯的?(複選題)
#(1) 7eleven
#(2) pcschool&python
#(3) Pcschool python
#(4) if
答:有下定義就都可以

# %%
7eleven
# Out:
#   Cell In[26], line 1
#     7eleven
#     ^
# SyntaxError: invalid decimal literal

# %%
name = '7eleven'

# %%
pcschool&python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\職訓\第二周\第二周\0911\徐國堂0911\GitHub\2023_09_11_hw1\1.python基礎與資料輸出.ipynb 儲存格 25 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> pcschool&python
#
# NameError: name 'pcschool' is not defined

# %%
name =' pcschool&python'

# %%
Pcschool python
# Out:
#   Cell In[31], line 1
#     Pcschool python
#              ^
# SyntaxError: invalid syntax

# %%
name = 'Pcschool python'

# %%
if
# Out:
#   Cell In[33], line 1
#     if
#       ^
# SyntaxError: invalid syntax

# %%
name = 'if'

# %%
#question: 若要建立 x 變數內容為 15，請問哪一行是對的? (選擇題)
#(1) x equals 15  (2) x is 15  (3) 15 = x  (4) x = 15
答:(4)

# %%
x equals 15
# Out:
#   Cell In[35], line 1
#     x equals 15
#       ^
# SyntaxError: invalid syntax

# %%
x is 15
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\PowerUser\AppData\Local\Temp\ipykernel_8212\1640031689.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   x is 15
# C:\Users\PowerUser\AppData\Local\Temp\ipykernel_8212\1640031689.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   x is 15
# C:\Users\PowerUser\AppData\Local\Temp\ipykernel_8212\1640031689.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   x is 15
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\職訓\第二周\第二周\0911\徐國堂0911\GitHub\2023_09_11_hw1\1.python基礎與資料輸出.ipynb 儲存格 33 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> x is 15
#
# NameError: name 'x' is not defined

# %%
15 = x
# Out:
#   Cell In[37], line 1
#     15 = x
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
x = 15

# %%
#關於註解
'''註解就是程式的說明文字
單行註解，可於程式碼中加入「#」作為單行註解，於「#」之後的該行語法都不會執行。
pcschool=100 #pcschool 儲存 100 這個內容
多行註解，可於註解區塊前後加上三個單引號或三個雙引號方式。'''

# %%
#變數給值與輸出
'''如何給值?
請使用「=」這個符號，「=」代表右邊丟給左邊，而左邊得接受這個資料。
在建立變數之前，也就是給變數內容之前，嘗試存取某個變數會發生變 數未定義的錯誤。
print 代表資料輸出，也是存取內容的動作，基本語法為 print(變數) 或者 print(內容)。
內容會被雙引號或者單引號包夾起來。'''

# %%
#一個參數
print(3)
print(3.12)
print("Hello! World!")
print(3+2)
# Out:
# 3
# 3.12
# Hello! World!
# 5

# %%
#多個參數
a = 100
print('a=',a)
b = 50
print('b=', b)
print("a+b=", a+b)
# Out:
# a= 100
# b= 50
# a+b= 150

# %%
'''question:關於輸出語法哪一個是對的?(選擇題)
(1) print 3 + 4
(2) print(3 + 4)
(3) print 3 + 4
(4) put(3 + 4)'''
答:全錯,print(3+4)=7

# %%
print 3 + 4
# Out:
#   Cell In[40], line 1
#     print 3 + 4
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
(2) print(3 + 4)
# Out:
#   Cell In[41], line 1
#     (2) print(3 + 4)
#         ^
# SyntaxError: invalid syntax

# %%
print 3 + 4
# Out:
#   Cell In[42], line 1
#     print 3 + 4
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
put(3 + 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\職訓\第二周\第二周\0911\徐國堂0911\GitHub\2023_09_11_hw1\1.python基礎與資料輸出.ipynb 儲存格 43 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> put(3 + 4)
#
# NameError: name 'put' is not defined

# %%
print(3+4)
# Out:
# 7

# %%
'''question:請問 Python 檔案副檔名哪一個是對的?(選擇題)
(1) .script
(2) .pyscript
(3) .py
(4) .python'''
答:(3)

# %%
'''question: 請問執行這一行後的說明哪一個是對的?(選擇題)
print(x1)
(1) 產生錯誤
(2) 輸出空白
(3) 輸出 0'''
答:(1)

# %%
print(x1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\職訓\第二周\第二周\0911\徐國堂0911\GitHub\2023_09_11_hw1\1.python基礎與資料輸出.ipynb 儲存格 47 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#Y131sZmlsZQ%3D%3D?line=0'>1</a> print(x1)
#
# NameError: name 'x1' is not defined

# %%
'''Python內建資料型別
Python 的變數並沒有設定固定型態。
變數型態有整數、浮點數、布林值、字串。
• booleans (True or False)
• integers (42 and 100000000)
• floats (3.14159）
• string

var1=20	         var1 是整數，也就是 int 型態。
var2=123.45	     var2 是浮點數，也就是 float 型態。
var3=True	     var3 是布林值，也就是 True 或者 False。
var4=‘string1’	 var4 是字串 str，可用單引號或雙引號包起來。'''

# %%
'''資料型態
如何知道變數的資料型態?
可使用 type( ) 指令顯示。
變數內容變更後會儲存於不同的記憶體位址。那要如何查詢位址呢?
可使用 id( ) 指令顯示。'''

# %%
a = 100
print(type(a))
a
# Out:
# <class 'int'>
# 100

# %%
a = 100.0
print(type(a))
a
# Out:
# <class 'float'>
# 100.0

# %%
a = '100.0'
print(type(a))
a
# Out:
# <class 'str'>
# '100.0'

# %%
a = True
print(type(a))
a
# Out:
# <class 'bool'>
# True

# %%
#下面2行，將7給變數a, 並且輸出變數a的內容
a=7
print(a)
# Out:
# 7

# %%
#將a的參考給b,並且輸出變數b的內容
b=a
print(b)
b
# Out:
# True
# True

# %%
#使用type function輸出目前的資料型別
type(a) 
a
# Out:
# True

# %%
type(b)
b
type(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\職訓\第二周\第二周\0911\徐國堂0911\GitHub\2023_09_11_hw1\1.python基礎與資料輸出.ipynb 儲存格 57 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> type(b)
#       <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> b
#       <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> type(b)
#
# NameError: name 'b' is not defined

# %%
b = a
type(b)
# Out:
# bool

# %%
type(58)
# Out:
# int

# %%
type(99.9)
# Out:
# float

# %%
type('abc')
# Out:
# str

# %%
#資料型態:請動手操作，並留意輸出結果(type1.py)
var1=20 
print(type(var1))
var2=123.45
print(type(var2))
var3=True 
print(type(var3)) 
var4='string1' 
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
#資料型態:請動手操作，並留意輸出結果(type2.py)
a=5
a=20
print(id(a))
a="test" 
print(id(a))
# Out:
# 2260838187856
# 2260844228400

# %%
'''Question:請問執行這兩行後記憶體位址會相同嗎?(選擇題)
a=5.4
a=20.3
(1) 相同
(2) 不同'''
答:(1)

# %%
a=5.4

# %%
a=20.3

# %%
'''字串輸出格式化
舊的語法:
字串 % (變數,變數)

符號	說明
%%	在字串 中顯示%
# %d	以10 進位整數方式輸出
# %f	將浮點 數以10進位方式輸出
# %e, %E	將浮點 數以10進位方式輸出，並使用科學記號
# %o	以8進 位整數方式輸出
# %x, %X	將整數以16進位方式輸出
# %s	使用str()將字串輸出
# %c	以字元方式輸出

#可以在輸出浮點數時指定精度 
>>> 'example:%.2f' % 19.234
'example:19.23'

#也可以指定輸出時，至少要預留的字元寬度
#由於預留了6個字元寬度，不足的部份要由空白字元補上。使用%運算子來格式化字串，會產生新的字串物件。
>>> "example:%6.2f" % 19.234
'example: 19.23'
>>>

#在格式化時，也可以使用關鍵字來指定
>>> '%(real)s is %(nick)s!!' % ({'real' : 'Justin', 'nick' : 'caterpillar'})
'Justin is caterpillar!!'
>>>'''

# %%
'''新的語法:
字串.format(變數,變數...)  
#不指定位置，依序輸出
>>> "{} {} {}".format("A", "B", "C")
A B C

#用數字指定位置
"{2} {0} {1}".format("A", "B", "C") 
C A B

#用名稱指定位置
"{a} {c} {b}".format(a="A", b="B", c="C")
A C B'''

# %%
'''數值格式化及對齊
格式化的方式是在後方加上”:“及”格式符”，可用的格式符如下
{:d}        : 整數
{:f}        : 浮點數
{:e} {:E}   : 科學記號，例如 1.020000e+01，大小寫就代表 "e" 顯示的大小寫
{:x} {:X}   : 十六進位，大小寫分別表示 A ~ F 要顯示的大小寫
{:o}        : 八進位
{:b}        : 二進位
{:>}}        : 以百分比的方式輸出
另外可以使用 > ^ < 這三種符號以及數值來搭配佔位及對齊。注意: 數值型別預設是靠右對齊，字串型別預設是靠左對齊

{:>8d}      : 整數靠右對齊，寬度為 8
{:^8d}      : 整數置中對齊，寬度為 8
{:<8d}      : 整數靠左對齊，寬度為 8
{:8.3f}     : 小數點後保留 3 位，總寬度為 8 (含小數點)
{:+8.3f}    : 小數點後保留 3 位，帶正負號，總寬度為 8 (含小數點及正負號)'''

# %%
'''#‘:’ 前方的數值如基本操作，代表後方參數的位置
print "|{0:8d}||{1:<8d}|".format(123, 456)
 |     123||456     |
print("|{0:+8.2f}|".format(4.32))
 |   +4.32|
print("|{0:8.2>}}|".format(0.8))
 |  80.00%|
 
字串與數值輸出預設對齊方式的比較
print("|{0:8}|".format(123))
 |     123|
print("|{0:8}|".format("abc"))
 |abc     | '''

# %%
#字串插補(快速寫法)
text = 'world'
print(f'Hello, {text}')
# Out:
# Hello, world

# %%
x = 10
y = 27

print(f'x + y = {x + y}')
# Out:
# x + y = 37

# %%
def hello(text, name):
    return f'hello {text}, hello {name}'
    f = 'hello'
f
hello
text
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\職訓\第二周\第二周\0911\徐國堂0911\GitHub\2023_09_11_hw1\1.python基礎與資料輸出.ipynb 儲存格 73 line 4
#       <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a>     return f'hello {text}, hello {name}'
#       <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a>     f = 'hello'
# ----> <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> f
#       <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X43sZmlsZQ%3D%3D?line=4'>5</a> hello
#       <a href='vscode-notebook-cell:/d%3A/%E8%81%B7%E8%A8%93/%E7%AC%AC%E4%BA%8C%E5%91%A8/%E7%AC%AC%E4%BA%8C%E5%91%A8/0911/%E5%BE%90%E5%9C%8B%E5%A0%820911/GitHub/2023_09_11_hw1/1.python%E5%9F%BA%E7%A4%8E%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%87%BA.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> text
#
# NameError: name 'f' is not defined
